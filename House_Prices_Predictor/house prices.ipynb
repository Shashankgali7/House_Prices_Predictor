# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv('D:\\Kaggle\\House Prices\\train.csv')
test=pd.read_csv('D:\\Kaggle\\House Prices\\test.csv')

# %%
c_train=train.copy()
c_test=test.copy()
c_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
c_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
c_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
c_train.shape,c_test.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
c_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
c_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
train['c_train']  = 1
test['c_train']  = 0
df=pd.concat([train,test],axis=0,sort=False)

# %%
nv = [(c, df[c].isna().mean()*100) for c in df]
nv=pd.DataFrame(nv,columns=['column_name','Percentage'])

# %%
nv = nv[nv.Percentage > 50]
nv.sort_values("Percentage", ascending=False)
# Out:
#     column_name  Percentage
# 72       PoolQC   99.657417
# 74  MiscFeature   96.402878
# 6         Alley   93.216855
# 73        Fence   80.438506

# %%
df=df.drop(['PoolQC','MiscFeature','Alley','Fence'],axis=1)

# %%
objects_column=df.select_dtypes(include=['object'])

# %%
numerical_column=df.select_dtypes(exclude=['object'])

# %%
objects_column.dtypes
# Out:
# MSZoning         object
# Street           object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# MasVnrType       object
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# KitchenQual      object
# Functional       object
# FireplaceQu      object
# GarageType       object
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# PavedDrive       object
# SaleType         object
# ...

# %%
numerical_column.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1       float64
# BsmtFinSF2       float64
# BsmtUnfSF        float64
# TotalBsmtSF      float64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath     float64
# BsmtHalfBath     float64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars       float64
# GarageArea       float64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# ...

# %%
null_counts=objects_column.isnull().sum()
print(null_counts)
# Out:
# MSZoning            4
# Street              0
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         24
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           81
# BsmtCond           82
# BsmtExposure       82
# BsmtFinType1       79
# BsmtFinType2       80
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# KitchenQual         1
# Functional          2
# FireplaceQu      1420
# GarageType        157
# GarageFinish      159
# GarageQual        159
# GarageCond        159
# PavedDrive          0
# SaleType            1
# SaleCondition       0
# dtype: int64

# %%
columns_None = ['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','GarageType','GarageFinish','GarageQual','FireplaceQu','GarageCond']
objects_column[columns_None]= objects_column[columns_None].fillna('None')
# Out:
# C:\Users\sharv\anaconda3\lib\site-packages\pandas\core\frame.py:3062: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
columns_with_lowNA = ['MSZoning','Utilities','Exterior1st','Exterior2nd','MasVnrType','Electrical','KitchenQual','Functional','SaleType']
#fill missing values for each column (using its own most frequent value)
objects_column[columns_with_lowNA] = objects_column[columns_with_lowNA].fillna(objects_column.mode().iloc[0])

# %%
null_counts = numerical_column.isnull().sum()
print("Number of null values in each column:\n{}".format(null_counts))
# Out:
# Number of null values in each column:
# Id                  0
# MSSubClass          0
# LotFrontage       486
# LotArea             0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# MasVnrArea         23
# BsmtFinSF1          1
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        2
# BsmtHalfBath        2
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# TotRmsAbvGrd        0
# Fireplaces          0
# GarageYrBlt       159
# GarageCars          1
# GarageArea          1
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# MiscVal             0
# MoSold              0
# YrSold              0
# SalePrice        1459
# c_train             0
# dtype: int64

# %%
print((numerical_column['YrSold']-numerical_column['YearBuilt']).median())
print(numerical_column["LotFrontage"].median())
# Out:
# 35.0
# 68.0

# %%
numerical_column['GarageYrBlt'] = numerical_column['GarageYrBlt'].fillna(numerical_column['YrSold']-35)
numerical_column['LotFrontage'] = numerical_column['LotFrontage'].fillna(68)
# Out:
# <ipython-input-24-60eea7725e93>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical_column['GarageYrBlt'] = numerical_column['GarageYrBlt'].fillna(numerical_column['YrSold']-35)
# <ipython-input-24-60eea7725e93>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical_column['LotFrontage'] = numerical_column['LotFrontage'].fillna(68)

# %%
numerical_column=numerical_column.fillna(0)

# %%
import matplotlib.pyplot as plt
objects_column['Utilities'].value_counts().plot(kind='bar',figsize=[10,3])
objects_column['Utilities'].value_counts()
# Out:
# AllPub    2918
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
objects_column['Street'].value_counts().plot(kind='bar',figsize=[10,3])
objects_column['Street'].value_counts()
# Out:
# Pave    2907
# Grvl      12
# Name: Street, dtype: int64

# %%
objects_column['Condition2'].value_counts().plot(kind='bar',figsize=[10,3])
objects_column['Condition2'].value_counts()
# Out:
# Norm      2889
# Feedr       13
# Artery       5
# PosA         4
# PosN         4
# RRNn         2
# RRAn         1
# RRAe         1
# Name: Condition2, dtype: int64

# %%
objects_column['RoofMatl'].value_counts().plot(kind='bar',figsize=[10,3])
objects_column['RoofMatl'].value_counts()
# Out:
# CompShg    2876
# Tar&Grv      23
# WdShake       9
# WdShngl       7
# Metal         1
# Roll          1
# Membran       1
# ClyTile       1
# Name: RoofMatl, dtype: int64

# %%
objects_column['Heating'].value_counts().plot(kind='bar',figsize=[10,3])
objects_column['Heating'].value_counts()
# Out:
# GasA     2874
# GasW       27
# Grav        9
# Wall        6
# OthW        2
# Floor       1
# Name: Heating, dtype: int64

# %%
objects_column=objects_column.drop(['Utilities','Street','Condition2','RoofMatl','Heating'],axis=1)

# %%
numerical_column['Age_house']=(numerical_column['YrSold']-numerical_column['YearBuilt'])

# %%
Negatif=numerical_column[numerical_column['Age_house']<0]
Negatif
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 1089  2550          20        128.0    39290           10            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  EnclosedPorch  \
# 1089       2008          2009      1224.0      4010.0  ...              0
#
#       3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SalePrice  \
# 1089          0            0         0    17000      10    2007        0.0
#
#       c_train  Age_house
# 1089        0         -1
#
# [1 rows x 40 columns]

# %%
numerical_column.loc[numerical_column['Age_house']<0,'YrSold']=2009
numerical_column['Age_house']=(numerical_column['YrSold']-numerical_column['YearBuilt'])
numerical_column['Age_house'].describe()
# Out:
# count    2919.000000
# mean       36.480644
# std        30.335358
# min         0.000000
# 25%         7.000000
# 50%        35.000000
# 75%        54.500000
# max       136.000000
# Name: Age_house, dtype: float64

# %%
numerical_column['TotalBsmtBath']=numerical_column['BsmtFullBath']+numerical_column['BsmtHalfBath']*0.5
numerical_column['TotalBath']=numerical_column['FullBath']+numerical_column['HalfBath']*0.5

# %%
numerical_column['TotalSF']=numerical_column['TotalBsmtSF']+numerical_column['1stFlrSF']+numerical_column['2ndFlrSF']

# %%
numerical_column.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  PoolArea  MiscVal  MoSold  \
# 0          2003       196.0       706.0  ...         0        0       2
# 1          1976         0.0       978.0  ...         0        0       5
# 2          2002       162.0       486.0  ...         0        0       9
# 3          1970         0.0       216.0  ...         0        0       2
# 4          2000       350.0       655.0  ...         0        0      12
#
# ...

# %%
bin_map  = {'TA':2,'Gd':3, 'Fa':1,'Ex':4,'Po':1,'None':0,'Y':1,'N':0,'Reg':3,'IR1':2,'IR2':1,'IR3':0,"None" : 0,
            "No" : 2, "Mn" : 2, "Av": 3,"Gd" : 4,"Unf" : 1, "LwQ": 2, "Rec" : 3,"BLQ" : 4, "ALQ" : 5, "GLQ" : 6}

# %%
objects_column['ExterQual'] = objects_column['ExterQual'].map(bin_map)
objects_column['ExterCond'] = objects_column['ExterCond'].map(bin_map)
objects_column['BsmtCond'] = objects_column['BsmtCond'].map(bin_map)
objects_column['BsmtQual'] = objects_column['BsmtQual'].map(bin_map)
objects_column['HeatingQC'] = objects_column['HeatingQC'].map(bin_map)
objects_column['KitchenQual'] = objects_column['KitchenQual'].map(bin_map)
objects_column['FireplaceQu'] = objects_column['FireplaceQu'].map(bin_map)
objects_column['GarageQual'] = objects_column['GarageQual'].map(bin_map)
objects_column['GarageCond'] = objects_column['GarageCond'].map(bin_map)
objects_column['CentralAir'] = objects_column['CentralAir'].map(bin_map)
objects_column['LotShape'] = objects_column['LotShape'].map(bin_map)
objects_column['BsmtExposure'] = objects_column['BsmtExposure'].map(bin_map)
objects_column['BsmtFinType1'] = objects_column['BsmtFinType1'].map(bin_map)
objects_column['BsmtFinType2'] = objects_column['BsmtFinType2'].map(bin_map)
PavedDrive =   {"N" : 0, "P" : 1, "Y" : 2}
objects_column['PavedDrive'] = objects_column['PavedDrive'].map(PavedDrive)

# %%
rest_object_column = objects_column.select_dtypes(include=['object'])
objects_column=pd.get_dummies(objects_column,columns=rest_object_column.columns)

# %%
objects_column.head()
# Out:
#    LotShape  ExterQual  ExterCond  BsmtQual  BsmtCond  BsmtExposure  \
# 0         3          4          2         4         2             2
# 1         3          2          2         4         2             4
# 2         2          4          2         4         2             2
# 3         2          2          2         2         4             2
# 4         2          4          2         4         2             3
#
#    BsmtFinType1  BsmtFinType2  HeatingQC  CentralAir  ...  SaleType_ConLw  \
# 0             6             1          4           1  ...               0
# 1             5             1          4           1  ...               0
# 2             6             1          4           1  ...               0
# 3             5             1          4           1  ...               0
# 4             6             1          4           1  ...               0
#
#    SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# ...

# %%
df_final=pd.concat([objects_column,numerical_column],axis=1,sort=False)
df_final.head()
# Out:
#    LotShape  ExterQual  ExterCond  BsmtQual  BsmtCond  BsmtExposure  \
# 0         3          4          2         4         2             2
# 1         3          2          2         4         2             4
# 2         2          4          2         4         2             2
# 3         2          2          2         2         4             2
# 4         2          4          2         4         2             3
#
#    BsmtFinType1  BsmtFinType2  HeatingQC  CentralAir  ...  PoolArea  MiscVal  \
# 0             6             1          4           1  ...         0        0
# 1             5             1          4           1  ...         0        0
# 2             6             1          4           1  ...         0        0
# 3             5             1          4           1  ...         0        0
# 4             6             1          4           1  ...         0        0
#
#    MoSold  YrSold  SalePrice  c_train  Age_house  TotalBsmtBath  TotalBath  \
# ...

# %%
df_final = df_final.drop(['Id',],axis=1)

df_train = df_final[df_final['c_train'] == 1]
df_train = df_train.drop(['c_train',],axis=1)


df_test = df_final[df_final['c_train'] == 0]
df_test = df_test.drop(['SalePrice'],axis=1)
df_test = df_test.drop(['c_train',],axis=1)

# %%
target= df_train['SalePrice']
df_train = df_train.drop(['SalePrice'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df_train,target,test_size=0.33,random_state=0)

# %%
from xgboost import XGBRegressor
xgb =XGBRegressor( booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=0.6, gamma=0,
             importance_type='gain', learning_rate=0.01, max_delta_step=0,
             max_depth=4, min_child_weight=1.5, n_estimators=2400,
             n_jobs=1, nthread=None, objective='reg:linear',
             reg_alpha=0.6, reg_lambda=0.6, scale_pos_weight=1, 
             silent=None, subsample=0.8, verbosity=1)

# %%
xgb.fit(df_train,target)
# Out:
# [14:36:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.2.0/src/objective/regression_obj.cu:174: reg:linear is now deprecated in favor of reg:squarederror.
# [14:36:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.2.0/src/objective/regression_obj.cu:174: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.6, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=4,
#              min_child_weight=1.5, missing=nan, monotone_constraints='()',
#              n_estimators=2400, n_jobs=1, nthread=1, num_parallel_tree=1,
#              objective='reg:linear', random_state=0, reg_alpha=0.6,
#              reg_lambda=0.6, scale_pos_weight=1, silent=None, subsample=0.8,
# ...

# %%
predict=xgb.predict(df_test)

# %%
submission = pd.DataFrame({
        "Id": test["Id"],
        "SalePrice": predict
    })
submission.to_csv('D:\\Kaggle\\House Prices\\submission.csv', index=False)
